# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('serving_layer.csv')
df[:10]
# Out:
# /tmp/ipykernel_37788/3444883065.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('serving_layer.csv')
#          date  stars  precipitation  precipitation_normal   min   max  \
# 0  2005-02-16    4.0           2.91                  0.98  64.0  49.0
# 1  2005-02-17    5.0           2.93                  1.01  63.0  47.0
# 2  2005-02-18    5.0           3.34                  1.05  54.0  51.0
# 3  2005-02-19    3.0           3.41                  1.08  61.0  49.0
# 4  2005-02-20    3.0           3.41                  1.11  63.0  48.0
# 5  2005-02-21    5.0           4.08                  1.14  54.0  47.0
# 6  2005-02-22    5.0           4.41                  1.18  56.0  45.0
# 7  2005-02-23    5.0           4.41                  1.21  59.0  47.0
# 8  2005-02-24    5.0           4.41                  1.24  63.0  47.0
# 9  2005-02-25    5.0           4.52                  1.27  62.0  46.0
#
# ...

# %%
df.corr()
# Out:
# /tmp/ipykernel_37788/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          stars  precipitation  precipitation_normal       min  \
# stars                 1.000000      -0.018718             -0.032254 -0.021228
# precipitation        -0.018718       1.000000              0.539859  0.030060
# precipitation_normal -0.032254       0.539859              1.000000  0.123786
# min                  -0.021228       0.030060              0.123786  1.000000
# max                  -0.027313       0.059267              0.143684  0.963133
# normal_min           -0.025929       0.057486              0.138300  0.921176
# normal_max           -0.025442       0.060872              0.142991  0.919491
#
#                            max  normal_min  normal_max
# ...

# %%
sns.heatmap(df.corr(), annot= True)
# Out:
# /tmp/ipykernel_37788/4014866372.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot= True)
# <Axes: >

# %%
df_stars_precipitation = df.drop(['date', 'precipitation_normal', 'min', 'max', 'normal_min', 'normal_max'], axis=1)
df_stars_precipitation
# Out:
#          stars  precipitation
# 0          4.0           2.91
# 1          5.0           2.93
# 2          5.0           3.34
# 3          3.0           3.41
# 4          3.0           3.41
# ...        ...            ...
# 6990275    5.0            NaN
# 6990276    3.0            NaN
# 6990277    5.0            NaN
# 6990278    5.0            NaN
# 6990279    5.0            NaN
#
# [6990280 rows x 2 columns]

# %%
sns.heatmap(df_stars_precipitation.corr(), annot= True)
# Out:
# <Axes: >

# %%
df_stars_min = df.drop(['date', 'precipitation_normal', 'precipitation', 'max', 'normal_min', 'normal_max'], axis=1)
df_stars_min
# Out:
#          stars   min
# 0          4.0  64.0
# 1          5.0  63.0
# 2          5.0  54.0
# 3          3.0  61.0
# 4          3.0  63.0
# ...        ...   ...
# 6990275    5.0   NaN
# 6990276    3.0   NaN
# 6990277    5.0   NaN
# 6990278    5.0   NaN
# 6990279    5.0   NaN
#
# [6990280 rows x 2 columns]

# %%
sns.heatmap(df_stars_min.corr(), annot=True)
# Out:
# <Axes: >

# %%
df_stars_max = df.drop(['date', 'precipitation_normal', 'precipitation', 'min', 'normal_min', 'normal_max'], axis=1)
df_stars_max
# Out:
#          stars   max
# 0          4.0  49.0
# 1          5.0  47.0
# 2          5.0  51.0
# 3          3.0  49.0
# 4          3.0  48.0
# ...        ...   ...
# 6990275    5.0   NaN
# 6990276    3.0   NaN
# 6990277    5.0   NaN
# 6990278    5.0   NaN
# 6990279    5.0   NaN
#
# [6990280 rows x 2 columns]

# %%
sns.heatmap(df_stars_max.corr(), annot=True)
# Out:
# <Axes: >
